# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.express as px

# %%
# Read in Data

data = pd.read_table('TaylorSwiftSongs.csv', delimiter=',')
data = data.drop('Unnamed: 0', axis=1)
data.loc[data['Album']=='The Taylor Swift Holiday Collection','Album'] = 'Holiday Collection'

# %%
# Play Count by Track Number

track_avg = list(data.groupby('Track Number', sort=True)['Play Count'].mean())
set0 = data[data['Set List']==0].groupby('Track Number', sort=True)['Play Count'].mean()
set1 = data[data['Set List']==1].groupby('Track Number', sort=True)['Play Count'].mean()
df = pd.DataFrame({'avg':track_avg, 'Not On Set List':set0, 'On Set List':set1})
df.index +=1

ax = sns.lineplot(data=df[['Not On Set List','On Set List']], palette=['red','blue'])
plt.xlabel('Track Number')
plt.ylabel('Play Count')
plt.title('Average Play Count by Track Number')
ax.grid(visible=True, which='major', color='black', linewidth=0.075);

# %%
album=(data['Album'].drop_duplicates()[0:11])
album_avg = data.groupby('Album', sort=False)['Play Count'].mean()[0:11]
set_list = data.groupby('Album', sort=False)['Set List'].sum()[0:11]
songs = data.groupby('Album', sort=False)['Title'].count()[0:11]

fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(go.Scatter(x=list(album), y=list(album_avg), name="Play Count"),secondary_y=False)
fig.add_trace(go.Scatter(x=list(album), y=list(songs), name="Songs on Album"),secondary_y=True)
fig.add_trace(go.Scatter(x=list(album), y=list(set_list), name='Songs Played on Eras Tour'),secondary_y=True)

fig.update_layout(title_text="")
fig.update_xaxes(title_text="Album")
fig.update_yaxes(title_text="Play Count", secondary_y=False)
fig.update_yaxes(title_text="Number of Songs", secondary_y=True)

fig.update_traces(marker=dict(size=30,
                              line=dict(width=2,
                                        color='DarkSlateGrey')),
                  selector=dict(mode='markers'))

fig.show()
fig.write_html("play-songs-set.html")
# Out:
# <div>                            <div id="e89083b3-2d4e-4de9-a203-21c03ca56112" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e89083b3-2d4e-4de9-a203-21c03ca56112")) {                    Plotly.newPlot(                        "e89083b3-2d4e-4de9-a203-21c03ca56112",                        [{"name":"Play Count","x":["Taylor Swift","Holiday Collection","Fearless","Speak Now","Red","1989","reputation","Lover","folklore","evermore","Midnights"],"y":[57164536.06666667,7322642.333333333,140786123.07692307,130377292.88235295,193874554.96551725,322918531.3125,322926993.6666667,300551901.2222222,249887142.2352941,163646843.82352942,196222243.75],"type":"scatter","xaxis":"x","yaxis":"y"},{"name":"Songs on Album","x":["Taylor Swift","Holiday Collection","Fearless","Speak Now","Red","1989","reputation","Lover","folklore","evermore","Midnights"],"y":[15,6,26,17,29,16,15,18,17,17,20],"type":"scatter","xaxis":"x","yaxis":"y2"},{"name":"Songs Played on Eras Tour","x":["Taylor Swift","Holiday Collection","Fearless","Speak Now","Red","1989","reputation","Lover","folklore","evermore","Midnights"],"y":[1,0,3,1,6,5,3,6,9,4,6],"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type" ...
